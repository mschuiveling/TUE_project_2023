# %% [markdown]
# # Creating a COCO Database
#
# This notebook is designed to create a COCO database from geojson and images originating from QuPath.
#
# ## Data Organization
#
# For successful execution, your data should be organized in the following structure:
#
# ### Data structure
# ```plaintext
# main_folder
# │
# ├── mark
# │   ├── file1.geojson
# │   ├── file2.geojson
# │   └── ...
# │
# ├── nadiya
# │   ├── file1.geojson
# │   ├── file2.geojson
# │   └── ...
# │
# └── rachelle
#     ├── file1.geojson
#     ├── file2.geojson
#     └── ...
# ```
# In the above structure:
# - `main_folder` is the root directory containing all the data.
# - Under `main_folder`, there are subfolders named `mark`, `nadiya`, and `rachelle`, each representing a different annotator.
# - Inside each annotator's folder, there are `.geojson` files representing the annotated data.

# %%
# import json
import glob
import os
import numpy as np
from pathlib import Path
import numpy as np
from pycocotools import mask
from skimage.draw import polygon
import pycocotools.mask as mask
import simplejson as json #installeer deze in pip

def json_serializer(obj):
    """Custom serializer for numpy types"""
    if isinstance(obj, (np.ndarray, np.integer, np.floating)):
        return obj.item()
    raise TypeError(f"Type {type(obj)} not serializable")

class COCODatasetGenerator:
    def __init__(self, geojson_path, output_file_name):
        self.geojson_path = geojson_path
        self.output_file_name = output_file_name
        self.image_nr = 0
        self.images = []
        self.annotations = []
        self.annotation_id = 1

    def generate_dataset(self):
        info = {
            "year": 2023,
            "version": "3",
            "description": "COCO_database_melanoma, open source dataset",
            "contributor": "M. Schuiveling",
            "coco_url" : "none",
            "absolute_url": "none",
            "url": "none",
            "date_created": "07/04/2023",
        }
        

        # Load image categories
        categories = [
            {"supercategory": "cells", "id": 1, "name": "Immune cells"},
            {"supercategory": "cells", "id": 2, "name": "Tumor"},
            # {"supercategory": "cells", "id": 3, "name": "Histiocyte"},
            # {"supercategory": "cells", "id": 4, "name": "Endothelium"},
            # {"supercategory": "cells", "id": 5, "name": "Melanophage"},
            # {"supercategory": "cells", "id": 6, "name": "Neutrophil"},
            # {"supercategory": "cells", "id": 7, "name": "Plasma cell"},
            # {"supercategory": "cells", "id": 8, "name": "Eosinophil"},
            {"supercategory": "cells", "id": 3, "name": "Other"},
        ]

        # Iterate over the JSON files in the folder
                # Iterate over all subfolders in the geojson_path
        for subdir, _, _ in os.walk(self.geojson_path):
            # Skip the parent directory
            if subdir == self.geojson_path:
                continue
            annotater = os.path.basename(subdir)
            for geojson_name in glob.glob(os.path.join(subdir, "*.geojson")):
                self.image_nr += 1

                # Extract image information and Load image information for coco database
                self.images.append(
                    {
                        "id": self.image_nr,
                        # "width": Image.open(geojson_name.replace(".geojson", ".png")).size,
                        # "height": Image.open(geojson_name.replace(".geojson", ".png")).size,
                        "width": 1024,
                        "height": 1024,
                        "file_name": str(geojson_name.replace(".geojson", ".png")),
                        "coco_url" : "none",
                        "absolute_url": "none",
                        'annotated_by': annotater,
                    }
                )

                # Load the JSON data from file
                with open(geojson_name) as f:
                    geojson_data = json.load(f)
        


                # Load annotations
                for feature in geojson_data["features"]:
                    segmentation = feature["geometry"]["coordinates"]
                    # GEOJSON also holds multipolygon which does not have a classification and holds list[list[int]] segmentation which gives errors
                    if feature["geometry"]["type"] == "Polygon" and len(segmentation[0]) > 8:
                        segmentation_flt_1 = [
                            [list(map(float, inner_list)) for inner_list in outer_list]
                            for outer_list in segmentation
                        ]
                        segmentation_flt_2 = segmentation_flt_1[0]
                        # print (segmentation_flt_2)
                        segmentation_flt_3 = []
                        for sublist in segmentation_flt_2:
                            for element in sublist:
                                segmentation_flt_3.append(element)
                        # print (segmentation_flt_2)
                        # print (segmentation_flt_3)
                        rle = mask.frPyObjects(
                            [segmentation_flt_3],1024,1024)
                        # print (rle)


                        classification = feature["properties"].get("classification", {})
                        # Map the category name to its ID, default is 9 (other)
                        category_id = {
                            "Immune cells": 1,
                            'Lymphocyte': 1,
                            "lymphocyte": 1,
                            "Tumor": 2,
                            # "Histiocyte": 3,
                            # "Endothelium": 4,
                            # "Melanophage": 5,
                            # "Neutrophil": 6,
                            # "Plasma cell": 7,
                            # "Eosinophil": 8 
                            #  for now all other cells are classified as other to see whether training is at all possible with this dataset
                        }.get(classification.get("name", ""), 3)

                        # Create bbox coordinates
                        x = [point[0] for point in segmentation[0]]
                        y = [point[1] for point in segmentation[0]]
                        xmin = min(x)
                        xmax = max(x)
                        ymin = min(y)
                        ymax = max(y)
                        bbox = float(xmin), float(ymin), float(xmax - xmin), float(ymax - ymin)
                        if xmax-xmin < 0.1:
                            print (geojson_name)
                        
                        # create larger bbox to take more context
                        self.annotations.append(
                            {
                                "id": self.annotation_id,  # Assign the current annotation_id
                                "image_id": self.image_nr,
                                "category_id": category_id,
                                # "area": polygon_area(segmentation_flt_2),
                                "area": mask.area(rle),
                                "segmentation": rle[0],
                                "bbox": bbox,
                                "bbox_mode": 1,
                                "iscrowd": 0,
                                
                                
                            }
                        )
                        self.annotation_id += 1  # Increment the annotation_id for the next annotation
        
        for category in categories:
            if category["name"] == "Immune cells":
                category["name"] = "immune_cell"
            elif category["name"] == "Tumor":
                category["name"] = "tumor"
            elif category["name"] == "Other":
                category["name"] = "other"

        coco_data = {
            "info": info,
            "categories": categories,
            "images": self.images,
            "annotations": self.annotations,
        }

        # Convert the output to a text file
        print (self.output_file_name, 'has been formed' )
        with open(os.path.join(self.geojson_path, self.output_file_name), "w") as f:
            f.write(json.dumps(coco_data, default=json_serializer, ignore_nan=True))


# Define the path to the GeoJSON (and image) files and the output file name
main_folder = "/mnt/d/TIL_Melanoma_train_database/cell_segmentation/open_source_dataset_tiles_final" # path to the folder containing the geojson files
output_file_name = "til_melanoma.json"
dataset_generator = COCODatasetGenerator(main_folder, output_file_name)
dataset_generator.generate_dataset()
# Out:
# til_melanoma.json has been formed
